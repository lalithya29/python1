# %%
x=10
y=20
print(x+y)

x=2
x+=3
print(x)
x-=6
print(x)

y=10
y*=4
print(y)
y=20
y/=10
print(y)

y%=2
print(y)

y=4
y//=2
print(y)

x=4
x**=2
print(x)

x=8
print(x>=5)

print(x<=10)

print(x!=10)

print(x==12)

print(x>5)
a=10
print(a!=10)
# Out:
# 30
# 5
# -1
# 40
# 2.0
# 0.0
# 2
# 16
# True
# True
# True
# False
# True
# False

# %%
a=12;b=23;c=23
print(a>=2 and b<=6 and c>=7)

print(a>=4 and b!=2)

print(a>=3 or b<=4)
a='A';b='C'
print(a>='E' and b=='c')
print(a!='a')
print(a<='U' and b>='C')

print(1 and 2)

print(2 and 3 and 4)
print(2 or 4)

print(1 or 0 or 5)

print(0 or 4 )

print(not False)       

print(not 12)
# Out:
# False
# True
# True
# False
# True
# True
# 2
# 4
# 2
# 1
# 4
# True
# False

# %%
x=10;y=20;c=30
print(x+y+c)

print(x+y*c)

print(x%y*c)

print(x//y)

print(x/y)

print(x%y)

print(x**y)
x=y=c=20
print(c)
# Out:
# 60
# 610
# 300
# 0
# 0.5
# 10
# 100000000000000000000
# 20

# %%
#work
print(5 and 4 or 7)

print(9 or 1 and 2)

print(10==0 or 10!=9)

a=15;b=17
print(a>b and b<a or a==b)

print(10&2&4)

print(7&0&7)

print(9|1|4)

print(8<<3)

print(10>>3)

print(10^4)

print(11<<4)

print(2^3^10)

print(7^8^9)

print(9 and 3 or 4 ^ 7)

print(10<<2 and 10>>2)
# Out:
# 4
# 9
# True
# False
# 0
# 0
# 13
# 64
# 1
# 14
# 176
# 11
# 6
# 3
# 2
