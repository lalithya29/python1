# %%
cost=1000
noofpassengers=int(input("noofpassengers"))
def Railway_Ticket(From,To,noofpassengers,old,young,child):
        return
    
From=input("from")
To=input("to")
old=int(input("old"))
Discount=(20/100)*1000
amount=old*Discount
print("bill for old people",amount)
rem=noofpassengers-old
print("remaining people",rem)
young=0
child=0
rem2=0
amount1=0
amount2=0
if rem>0:#if remaining people greater than 0 it asks for young people input
   young=int(input("young")) 
   rem2=rem-young
   print("remainning people",rem2)
   if young<=rem:#it calculates amount of young people if young<rem
     amount1=young*cost
     print("bill for young people",amount1)
if rem2>0 : 
   child=int(input("child"))
   Discount=(50/100)*cost
   if child<=rem2:
      amount2=child*Discount
      print("bill for children",amount2)
d=amount+amount1+amount2
print(f"From-{From}")
print(f"To-{To}")
print(f"noofpassengers-{noofpassengers}")
print(f"old-{old}")
if young>rem:#if young people greater than remaining it will take young people value as 0
  young=0  
  print(f"young-{young}")
else:
  print(f"young-{young}")
if child>rem2:#if child people greater than remaining it will take child people value as 0
  child=0  
  print(f"child-{child}")
else:
    print(f"child-{child}")
print("Total amount for passengers",d)
   
Railway_Ticket(From,To,noofpassengers,old,young,child)
# Out:
# noofpassengers 4
# from hyd
# to vij
# old 3
# bill for old people 600.0
# remaining people 1
# young 1
# remainning people 0
# bill for young people 1000
# From-hyd
# To-vij
# noofpassengers-4
# old-3
# young-1
# child-0
# Total amount for passengers 1600.0
