# %%
#Nested List 
l=[1,[2,4,5],3,4] 
print(l[1]) 
print(l[1][2]) 
x=[7,8,[10,20,['a','b'],['c','d']]] 
print(x[2])#[10,20,['a','b'],['c','d']] 
print(x[2][2])#['a','b'] 
print(x[2][3])#['c','d']] 
print(x[2][3][1])#d
# Out:
# [2, 4, 5]
# 5
# [10, 20, ['a', 'b'], ['c', 'd']]
# ['a', 'b']
# ['c', 'd']
# d
