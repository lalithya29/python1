# %%
#List Methods 
a=[1,2,3] 
a.insert(1,2) 
print(a) 
a.extend([2,3]) 
print(a) 
a.append(1) 
print(a) 
print(a.index(2)) 
print(a.pop()) 
print(a.pop(2))   
a=[1,2,3,4,6,7] 
b=a.copy() 
print(b) 
print(a) 
a.clear() 
print(a) 
del b
# Out:
# [1, 2, 2, 3]
# [1, 2, 2, 3, 2, 3]
# [1, 2, 2, 3, 2, 3, 1]
# 1
# 1
# 2
# [1, 2, 3, 4, 6, 7]
# [1, 2, 3, 4, 6, 7]
# []

# %%
a=10 
print(id(a)) 
b=10 
print(id(b)) 
a=[10,20,30] 
print(id(a)) 
b=[10,20,30] 
print(id(b)) 
a.append(99) 
print(id(a),id(b)) 
print(a) 
print(b) 
a=[1,9,8,7] 
print(a) 
print(sorted(a)) 
print(a) 
a.sort(reverse=True) 
print(a) 
a.sort() 
print(a) 
print(min(a)) 
print(max(a)) 
a.reverse() 
print(a) 
t=() 
print(type(t)) 
l=[] 
print(type(l))
# Out:
# 140713479776984
# 140713479776984
# 2137603475712
# 2137603477120
# 2137603475712 2137603477120
# [10, 20, 30, 99]
# [10, 20, 30]
# [1, 9, 8, 7]
# [1, 7, 8, 9]
# [1, 9, 8, 7]
# [9, 8, 7, 1]
# [1, 7, 8, 9]
# 1
# 9
# [9, 8, 7, 1]
# <class 'tuple'>
# <class 'list'>

# %%
#Task in Class 
a=list(map(int,input().split())) 
print(a) 
b=list(map(str,input().split())) 
a.extend(b) 
print(a) 
c=list(map(bool,input().split())) 
a = c + a 
print(a) 
a.pop(2) 
print(a)
# Out:
#  1 2 3 4
# [1, 2, 3, 4]
#  4 5 6
# [1, 2, 3, 4, '4', '5', '6']
#  True
# [True, 1, 2, 3, 4, '4', '5', '6']
# [True, 1, 3, 4, '4', '5', '6']
