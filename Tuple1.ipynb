# %%
#Tuple Built-in Functions 
x=(1,1.23,False) 
print(x) 
print(x[0],x[2]) 
print(x[-1],x[-3]) 
print(x[1:]) 
print(x[::-1]) 
print(min(x))# built in fuctions 
print(max(x)) 
print(sum(x)) 
print(sorted(x)) 
print(len(x)) 
print(tuple(x)) 
print(x)
# Out:
# (1, 1.23, False)
# 1 False
# False 1
# (1.23, False)
# (False, 1.23, 1)
# False
# 1.23
# 2.23
# [False, 1, 1.23]
# 3
# (1, 1.23, False)
# (1, 1.23, False)
