# %%
#String Methods 
a="lalithya is good" 
print(a.upper()) 
print(a.lower()) 
print(a.capitalize()) 
print(a.title()) 
b="LalithyaA" 
print(b.swapcase())
# Out:
# LALITHYA IS GOOD
# lalithya is good
# Lalithya is good
# Lalithya Is Good
# lALITHYAa

# %%
#Character Type checking methods 
a="abcd" 
print(a.isalpha()) 
print(a.isdigit()) 
b="123" 
print(b.isdigit() )#returns true if the given string is in digit or superscript (power of number)(number^2 here 2 is superscript) 
c="2^2" 
print(b.isdigit()) 
d="1234" 
print(d.isnumeric())#it returns true if tHe given string is digits or fractions or subscripts(number below the value)(a1 here 1 is subscript)or roman 
d="0" 
print(d.isdigit()) 
a=" " 
print(a.isspace()) 
a="\t" 
print(a.isprintable()) 
a="123abd" 
print(a.isalnum()) 
a="title" 
print(a.islower()) 
a="Lalithya" 
print(a.isupper()) 
a="Lalithya Is Good" 
print(a.istitle())
# Out:
# True
# False
# True
# True
# True
# True
# True
# False
# True
# True
# False
# True

# %%
#searching and checking methods 
a="apple" 
print(a.find("p"))#it returns first occurence value 
print(a.find("o"))#it returns -1 when the value is not present 
print(a.rfind("p"))#it returns last index value 
print(a.rfind("q")) 
print(a.index("a"))#it returns index of value 
print(a.count("p"))#it returns count 
print(a.startswith("a"))#it returns true if it starts with particular value
print(a.endswith("e"))#it returns true if it ends with particular value
# Out:
# 1
# -1
# 2
# -1
# 0
# 2
# True
# True

# %%
#Modification Methods 
a=" lalithya " 
print(a.strip()) 
print(a.lstrip()) 
print(a.rstrip()) 
print(a.replace("lith","s")) 
print(a.replace("y",""))#we can use replace to remove particular character in string
# Out:
# lalithya
# lalithya
#  lalithya
#  lasya
#  lalitha

# %%
#splitting and joining methods 
a="lalithya, is" 
print(a.split())#it trys to split at spaces 
print(a.split(","))#it trys to split at commas 
print('-'.join(a))#it trys to join with - 
print('*'.join(a))
# Out:
# ['lalithya,', 'is']
# ['lalithya', ' is']
# l-a-l-i-t-h-y-a-,- -i-s
# l*a*l*i*t*h*y*a*,* *i*s

# %%
#Advance Formatting 
a='6ls' 
print(a.zfill(5))#it adds leading 0 to string to match width 
print(a.ljust(5,"*"))#it moves string to left and add operator to match width 
print(a.rjust(2,"*"))#it moves string to right and add operator to matchh width 
print(a.center(4,"*")) 
print(a.partition("l"))#it separats the string in to three parts before and after separator 
a="StraßĦe" 
print(a.casefold())#it converts unicode characters to lower case letters     
#note :press windows +r to open character map
# Out:
# 006ls
# 6ls**
# 6ls
# 6ls*
# ('6', 'l', 's')
# strassħe

# %%
#String Formatting in Python 
#i)Using .format() Method: 
#.format() 
a="lalithya" 
college="SRKR" 
print("my name is {}.i Recently completed my graduation in{}".format(a,college)) 
print("i love my {1}and {0}".format("dad","mom")) 
#ii)Using f string  
#f string 
a="lalithya" 
b="VRK prasad" 
print(f"my name is {a} and iam the daughter of {b}") 
#iii)Using % format 
#% formating 
a="python" 
b="high demand" 
c=2026 
print("%s is having %s in %d"%(a,b,c))
# Out:
# my name is lalithya.i Recently completed my graduation inSRKR
# i love my momand dad
# my name is lalithya and iam the daughter of VRK prasad
# python is having high demand in 2026

# %%
#work
#replace all occurences of a with @
a="lalithya"
print(a.replace('a','@'))

#print first and last charcter of a string
a="lalithya"
print(a[0],a[-1])

#convert string to upper and lower case 
a="laLitHya"
print(a.upper(),a.lower())

#remove all spaces from a given string
a=" la lithy a"
print(a.replace(" ",''))
#or
a=" la lithy a"
print(''.join(a.split(" ")))

#check if wor d python is exist
a="lalithya"
print("python" in a)

#print first three characters of given string
a="lalithya"
print(a[0],a[1],a[2])

#merge two strings
a="lalithya"
b="is good"
print(a+b)

#check if string contains only digits
a="lalithya"
print(a.isdecimal())

#remove all occurences of e
a="east or west"
print(a.replace("e"," "))

#count of given string
a='book'
print(a.count('o'))

#check if user contains letters and numbers
a='lalithya19'
print(a.isalnum())
# Out:
# l@lithy@
# l a
# LALITHYA lalithya
# lalithya
# lalithya
# False
# l a l
# lalithyais good
# False
#  ast or w st
# 2
# True

# %%
#check if an email has @ and ends with .com
a="lalvan@gmail.com"
print("@"in a and a.endswith(".com"))

#check whether the given string contains atleast 8 characters,num,special character
a="Lalithya@123"
print(len(a)>=8 and a.isalnum()==False)

#check the length of given string
a="lalitya"
len=0
for i in a:
    len=len+1
print(len)

#reverse given string
a="lalithya"
print(a[::-1])

#count of vowels
a="lalithya"
c=0
for i in a:
    if i in "aeiou":
       c=c+1
print(c)

#count of consonents
a="lalithya"
c=0
for i in a:
    if i not in "aeiou":
       c=c+1
print(c)
# Out:
# True
# True
# 7
# ayhtilal
# 3
# 5
